# %%
import langchain
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
from langchain.chains.openai_functions.openapi import get_openapi_chain

chain = get_openapi_chain(
    "https://raw.githubusercontent.com/mnshah0101/billy-bets/main/nfl/docs_edit.json", 
    llm= 'gpt-3.5'
)
chain("How many games are being played right now?", )
# Out:
# Attempting to load an OpenAPI 3.0.1 spec.  This may result in degraded performance. Convert your OpenAPI spec to 3.1.* spec for better support.
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In [27], line 6
#       1 from langchain.chains.openai_functions.openapi import get_openapi_chain
#       3 chain = get_openapi_chain(
#       4     "https://raw.githubusercontent.com/mnshah0101/billy-bets/main/nfl/docs_edit.json"
#       5 )
# ----> 6 chain("How many games are being played right now?")
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# ...

# %%
from langchain.chains.api import openapi
